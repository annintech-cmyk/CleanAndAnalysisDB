# %%
import pandas as pd
artworks_100 = pd.read_csv("file/Artworks.txt")

# %%
artworks_100.to_csv('file/new_file_name.csv', index=False)

# %%
artworks_100 = pd.read_csv("file/new_file_name.csv")
print(artworks_100.head(10))
# Out:
#                                                Title  \
# 0  Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1  City of Music, National Superior Conservatory ...
# 2  Villa project, outside Vienna, Austria (Elevat...
# 3  The Manhattan Transcripts Project, New York, N...
# 4  Villa project, outside Vienna, Austria (Exteri...
# 5  The Manhattan Transcripts Project, New York, N...
# 6  The Manhattan Transcripts Project, New York, N...
# 7  The Manhattan Transcripts Project, New York, N...
# 8  The Manhattan Transcripts Project, New York, N...
# 9  The Manhattan Transcripts Project, New York, N...
#
#                      Artist ConstituentID  \
# 0               Otto Wagner          6210
# 1  Christian de Portzamparc          7470
# 2                Emil Hoppe          7605
# 3           Bernard Tschumi          7056
# 4                Emil Hoppe          7605
# 5           Bernard Tschumi          7056
# 6           Bernard Tschumi          7056
# ...

# %%
# Check the distribution of values in the 'Date' column
artworks_100['Date'].value_counts()
# Out:
# Date
# n.d.           2060
# 1967           2058
# 1965           1987
# 1970           1964
# 1971           1901
#                ...
# 2010–2022         1
# 2023–2025         1
# 1964–1965         1
# 2017 - 2024       1
# 2026              1
# Name: count, Length: 8514, dtype: int64
