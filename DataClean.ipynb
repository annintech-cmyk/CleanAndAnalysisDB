# %%
import pandas as pd
from pandas import to_numeric

born = pd.read_csv("file/bios.csv")
born.head()
df = born.copy()
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  str
#  2   born_date     143693 non-null  str
#  3   born_city     110908 non-null  str
#  4   born_region   110908 non-null  str
#  5   born_country  110908 non-null  str
#  6   NOC           145499 non-null  str
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   str
# dtypes: float64(2), int64(1), str(7)
# memory usage: 11.1 MB

# %%
print(df.head(5))
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
df["born_year"] = df["born_date"].str.split('-', n=1).str.get(0)

# %%
print(df.head(5))
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date born_year
# 0  1960-10-02      1886
# 1         NaN      1969
# 2  1994-07-17      1898
# 3  1978-03-20      1895
# 4  1930-07-25      1878

# %%
df["born_year"] = pd.to_numeric(df["born_year"], errors='coerce')

# %%
df["born_year"]
# Out:
# 0         1886.0
# 1         1969.0
# 2         1898.0
# 3         1895.0
# 4         1878.0
#            ...
# 145495    2002.0
# 145496    1999.0
# 145497    1998.0
# 145498    1899.0
# 145499    1913.0
# Name: born_year, Length: 145500, dtype: float64

# %%
df["born_year"].dtype
# Out:
# dtype('float64')

# %%
print(df.head(10))
# Out:
#    athlete_id                   name   born_date          born_city  \
# 0           1  Jean-François Blanchy  1886-12-12           Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01             Meulan
# 2           3           Jean Borotra  1898-08-13           Biarritz
# 3           4        Jacques Brugnon  1895-05-11        Paris VIIIe
# 4           5           Albert Canet  1878-04-17         Wandsworth
# 5           6      Nicolas Chatelain  1970-01-13             Amiens
# 6           7          Patrick Chila  1969-11-27        Ris-Orangis
# 7           8           Henri Cochet  1901-12-14       Villeurbanne
# 8           9          Marcel Cousin  1896-08-04              Nîmes
# 9          10     Guy de la Chapelle  1868-07-16  Farges-Allichamps
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# ...

# %%
datatype = df["born_year"].dtype
print(datatype)

print(df["born_year"].isnull().sum())
# Out:
# float64
# 1807

# %%
df.count()
# Out:
# athlete_id      145500
# name            145500
# born_date       143693
# born_city       110908
# born_region     110908
# born_country    110908
# NOC             145499
# height_cm       106651
# weight_kg       102070
# died_date        33940
# born_year       143693
# dtype: int64

# %%
df.dtypes
# Out:
# athlete_id        int64
# name                str
# born_date           str
# born_city           str
# born_region         str
# born_country        str
# NOC                 str
# height_cm       float64
# weight_kg       float64
# died_date           str
# born_year       float64
# dtype: object

# %%
born_1990 = df[df["born_year"] == 1901]
born_1990.count()
# Out:
# athlete_id      516
# name            516
# born_date       516
# born_city       428
# born_region     428
# born_country    428
# NOC             516
# height_cm       139
# weight_kg        95
# died_date       451
# born_year       516
# dtype: int64

# %%
df["Measurements"] = df["height_cm"].astype(str) + "/" + df["weight_kg"].astype(str)

# %%
print(df.head())
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date  born_year Measurements
# 0  1960-10-02     1886.0          NaN
# 1         NaN     1969.0   183.0/76.0
# 2  1994-07-17     1898.0   183.0/76.0
# ...

# %%
df.drop("height_cm", axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  str
#  2   born_date     143693 non-null  str
#  3   born_city     110908 non-null  str
#  4   born_region   110908 non-null  str
#  5   born_country  110908 non-null  str
#  6   NOC           145499 non-null  str
#  7   weight_kg     102070 non-null  float64
#  8   died_date     33940 non-null   str
#  9   born_year     143693 non-null  float64
#  10  Measurements  102070 non-null  str
# dtypes: float64(2), int64(1), str(8)
# memory usage: 12.2 MB

# %%
df.drop("weight_kg", axis=1, inplace=True)

# %%
df[["height_cm", "weight_kg"]]= df["Measurements"].str.split("/", n=1, expand=True)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  str
#  2   born_date     143693 non-null  str
#  3   born_city     110908 non-null  str
#  4   born_region   110908 non-null  str
#  5   born_country  110908 non-null  str
#  6   NOC           145499 non-null  str
#  7   died_date     33940 non-null   str
#  8   born_year     143693 non-null  float64
#  9   Measurements  102070 non-null  str
#  10  height_cm     102070 non-null  str
#  11  weight_kg     102070 non-null  str
# dtypes: float64(1), int64(1), str(10)
# memory usage: 13.3 MB

# %%
df["weight_kg"]
# Out:
# 0          NaN
# 1         76.0
# 2         76.0
# 3         64.0
# 4          NaN
#           ...
# 145495    61.0
# 145496    65.0
# 145497    55.0
# 145498     NaN
# 145499     NaN
# Name: weight_kg, Length: 145500, dtype: str

# %%
df.drop("Measurements", axis=1, inplace=True)

# %%
print(df.head())
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC   died_date  born_year height_cm  \
# 0               Gironde          FRA  France  1960-10-02     1886.0       NaN
# 1              Yvelines          FRA  France         NaN     1969.0     183.0
# 2  Pyrénées-Atlantiques          FRA  France  1994-07-17     1898.0     183.0
# 3                 Paris          FRA  France  1978-03-20     1895.0     168.0
# 4               England          GBR  France  1930-07-25     1878.0       NaN
#
#   weight_kg
# 0       NaN
# 1      76.0
# 2      76.0
# 3      64.0
# 4       NaN

# %%
df["NOC"].unique()
# Out:
# <StringArray>
# [                                          'France',
#                                     'Great Britain',
#                              'Germany West Germany',
#                                      'West Germany',
#                                           'Germany',
#                                             'Ghana',
#                                            'Greece',
#                                         'Guatemala',
#                                             'Haiti',
#                                  'Hong Kong, China',
#  ...
#                                      'Cuba Türkiye',
#                'Finland People's Republic of China',
#                                   'Czechia Germany',
#                                        'Korea Team',
#                      'Korea Team Republic of Korea',
#                                               'ROC',
#  'Democratic People's Republic of Korea Korea Team',
# ...

# %%
df["born_year"].unique()
# Out:
# array([1886., 1969., 1898., 1895., 1878., 1970., 1901., 1896., 1868.,
#        1874., 1882.,   nan, 1873., 1965., 1968., 1890., 1900., 1904.,
#        1881., 1875., 1863., 1963., 1973., 1891., 1972., 1967., 1877.,
#        1883., 1961., 1876., 1902., 1870., 1964., 1962., 1879., 1975.,
#        1872., 1871., 1897., 1971., 1966., 1869., 1960., 1880., 1955.,
#        1867., 1887., 1885., 1974., 1864., 1888., 1884., 1899., 1892.,
#        1959., 1893., 1958., 1952., 1950., 1953., 1956., 1976., 1979.,
#        1894., 1951., 1937., 1944., 1948., 1978., 1954., 1947., 1942.,
#        1935., 1945., 1946., 1934., 1957., 1889., 1949., 1866., 1913.,
#        1932., 1977., 1939., 1924., 1926., 1931., 1930., 1940., 1943.,
#        1936., 1933., 1858., 1849., 1861., 1929., 1852., 1857., 1941.,
#        1928., 1865., 1860., 1862., 1854., 1850., 1855., 1853., 1847.,
#        1859., 1846., 1856., 1903., 1927., 1938., 1910., 1906., 1914.,
# ...

# %%
df["born_year"] = df["born_year"].astype("Int64")

# %%
df.fillna(df["born_year"], inplace=True)
##df["born_year"]
df["born_year"].notnull().count()
# Out:
# np.int64(145500)

# %%
df.columns[df.isnull().any()]
# Out:
# Index(['born_date', 'born_city', 'born_region', 'born_country', 'NOC',
#        'died_date', 'born_year', 'height_cm', 'weight_kg'],
#       dtype='str')

# %%
df["born_year"].dtype
# Out:
# Int64Dtype()

# %%
df["born_year"].dtype
# Out:
# Int64Dtype()

# %%
ff = df[df.isnull()]
print(ff.count())
# Out:
# athlete_id      0
# name            0
# born_date       0
# born_city       0
# born_region     0
# born_country    0
# NOC             0
# died_date       0
# born_year       0
# height_cm       0
# weight_kg       0
# dtype: int64

# %%
df['weight_kg'] = df['weight_kg'].fillna(0)

# %%
mean = df['weight_kg'].mean()
print(mean)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[358], line 1
# ----> 1 mean = df['weight_kg'].mean()
#       2 print(mean)
#
# File ~/Documents/post_projects/Python/Analysis/.venv/lib/python3.14/site-packages/pandas/util/_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~/Documents/post_projects/Python/Analysis/.venv/lib/python3.14/site-packages/pandas/core/series.py:8113, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    8063 @deprecate_nonkeyword_arguments(Pandas4Warning, allowed_args=["self"], name="mean")
# ...

# %%
df['weight_kg'].notna()

# %%
df['weight_kg'].notna()

# %%
df.count()

# %%
df.dropna()

# %%
df.count()

# %%
df.duplicated()

# %%
df['weight_kg'].str.title()

# %%
print(df.head())

# %%
df["born_year"].head()

# %%
# Check all have /
fi = df[df["Measurements"].str.contains("/", na=False) ]
print(fi.head())

# %%
small_data = pd.DataFrame(['183 cm', '189cm / 150 kg','100 cm','100 kg', '190 cm/ 80kg'], columns=['Measurements'])
small_data.count()
print(small_data.head())

# %%
# Extract height (numbers before 'cm') and weight (numbers before 'kg')
small_data["height"] = small_data["Measurements"].str.extract(r'(\d+)\s*cm', expand=False)
small_data["Weight"] = small_data["Measurements"].str.extract(r'(\d+)\s*kg', expand=False)

# Convert to numeric
small_data["height"] = pd.to_numeric(small_data["height"], errors='coerce')
small_data["Weight"] = pd.to_numeric(small_data["Weight"], errors='coerce')

print(small_data)

# %%
#small_data[["height", "Weight"]] = small_data["Measurements"].str.split("/", n=1, expand=True)
print(small_data.head())

# %%
#small_data["height"] = small_data["height"].str.replace("cm","").str.strip()
print(small_data.head())

# %%
#small_data["Weight"] = small_data["Weight"].str.replace("kg","").str.strip()
print(small_data.head())

# %%
small_data.info()

# %%
height = small_data["Weight"].dropna()
vv = height.iloc[0]
print(vv)

# %%
df["weight_kg"] = df["weight_kg"].str.extract(r'(\d+)', expand=False)
print(df.head())

# %%
df["height_cm"] = df["height_cm"].str.extract(r'(\d+)', expand=False)
print(df.head())

# %%
# Convert to datetime
df["born_date"] = pd.to_datetime(df["born_date"], errors='coerce')

# Format as mm/dd/yyyy
df["born_date"] = df["born_date"].dt.strftime("%d %B %Y")

print(df.head())

# %%
df["born_date"] = pd.to_datetime(df["born_date"], errors="coerce")
df["born_date"] = df["born_date"].dt.strftime("%m-%d-%Y")

# %%
print(df.head())

# %%
data_pattern = "%d %B %Y"
df["Born"] = df["born_date"].str.extract(data_pattern, expand=False)

# %%
import numpy as np
print(df.columns)
df["born_year"].dtype

# %%
print(df.columns.tolist())

# %%
df["height_cm"].dtype
