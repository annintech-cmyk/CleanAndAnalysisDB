# %%
import pandas as pd
test = pd.read_csv("file/food_info.csv")
print(test)
print(test.size)
# Out:
#       NDB_No                   Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0       1001            BUTTER WITH SALT      15.87         717         0.85
# 1       1002    BUTTER WHIPPED WITH SALT      15.87         717         0.85
# 2       1003        BUTTER OIL ANHYDROUS       0.24         876         0.28
# 3       1004                 CHEESE BLUE      42.41         353        21.40
# 4       1005                CHEESE BRICK      41.11         371        23.24
# ...      ...                         ...        ...         ...          ...
# 8613   83110             MACKEREL SALTED      43.00         305        18.50
# 8614   90240  SCALLOP (BAY&SEA) CKD STMD      70.25         111        20.54
# 8615   90480                  SYRUP CANE      26.00         269         0.00
# 8616   90560                   SNAIL RAW      79.20          90        16.10
# 8617   93600            TURTLE GREEN RAW      78.50          89        19.80
#
# ...

# %%
print(test.size)
print(type(test))
print(test.head())
# Out:
# 310248
# <class 'pandas.DataFrame'>
#    NDB_No                 Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001          BUTTER WITH SALT      15.87         717         0.85
# 1    1002  BUTTER WHIPPED WITH SALT      15.87         717         0.85
# 2    1003      BUTTER OIL ANHYDROUS       0.24         876         0.28
# 3    1004               CHEESE BLUE      42.41         353        21.40
# 4    1005              CHEESE BRICK      41.11         371        23.24
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  ...  \
# 0          81.11     2.11            0.06           0.0           0.06  ...
# 1          81.11     2.11            0.06           0.0           0.06  ...
# 2          99.48     0.00            0.00           0.0           0.00  ...
# 3          28.74     5.11            2.34           0.0           0.50  ...
# 4          29.68     3.18            2.79           0.0           0.51  ...
#
# ...

# %%
column_name = test.columns.tolist()
print(column_name)
#shape
shape = test.shape
print(shape)
#Num of rows
print(f"Num Rows: ",shape[0])
print(f"Num Columns: ",shape[1])
# Out:
# ['NDB_No', 'Shrt_Desc', 'Water_(g)', 'Energ_Kcal', 'Protein_(g)', 'Lipid_Tot_(g)', 'Ash_(g)', 'Carbohydrt_(g)', 'Fiber_TD_(g)', 'Sugar_Tot_(g)', 'Calcium_(mg)', 'Iron_(mg)', 'Magnesium_(mg)', 'Phosphorus_(mg)', 'Potassium_(mg)', 'Sodium_(mg)', 'Zinc_(mg)', 'Copper_(mg)', 'Manganese_(mg)', 'Selenium_(mcg)', 'Vit_C_(mg)', 'Thiamin_(mg)', 'Riboflavin_(mg)', 'Niacin_(mg)', 'Vit_B6_(mg)', 'Vit_B12_(mcg)', 'Vit_A_IU', 'Vit_A_RAE', 'Vit_E_(mg)', 'Vit_D_mcg', 'Vit_D_IU', 'Vit_K_(mcg)', 'FA_Sat_(g)', 'FA_Mono_(g)', 'FA_Poly_(g)', 'Cholestrl_(mg)']
# (8618, 36)
# Num Rows:  8618
# Num Columns:  36

# %%
print(test.loc[0])
# Out:
# NDB_No                         1001
# Shrt_Desc          BUTTER WITH SALT
# Water_(g)                     15.87
# Energ_Kcal                      717
# Protein_(g)                    0.85
# Lipid_Tot_(g)                 81.11
# Ash_(g)                        2.11
# Carbohydrt_(g)                 0.06
# Fiber_TD_(g)                    0.0
# Sugar_Tot_(g)                  0.06
# Calcium_(mg)                   24.0
# Iron_(mg)                      0.02
# Magnesium_(mg)                  2.0
# Phosphorus_(mg)                24.0
# Potassium_(mg)                 24.0
# Sodium_(mg)                   643.0
# Zinc_(mg)                      0.09
# Copper_(mg)                     0.0
# Manganese_(mg)                  0.0
# Selenium_(mcg)                  1.0
# Vit_C_(mg)                      0.0
# Thiamin_(mg)                  0.005
# Riboflavin_(mg)               0.034
# Niacin_(mg)                   0.042
# Vit_B6_(mg)                   0.003
# Vit_B12_(mcg)                  0.17
# ...

# %%
print(test.loc[1])
# Out:
# NDB_No                                 1002
# Shrt_Desc          BUTTER WHIPPED WITH SALT
# Water_(g)                             15.87
# Energ_Kcal                              717
# Protein_(g)                            0.85
# Lipid_Tot_(g)                         81.11
# Ash_(g)                                2.11
# Carbohydrt_(g)                         0.06
# Fiber_TD_(g)                            0.0
# Sugar_Tot_(g)                          0.06
# Calcium_(mg)                           24.0
# Iron_(mg)                              0.16
# Magnesium_(mg)                          2.0
# Phosphorus_(mg)                        23.0
# Potassium_(mg)                         26.0
# Sodium_(mg)                           659.0
# Zinc_(mg)                              0.05
# Copper_(mg)                           0.016
# Manganese_(mg)                        0.004
# Selenium_(mcg)                          1.0
# Vit_C_(mg)                              0.0
# ...

# %%
print(test.loc[[3, 4]])
# Out:
#    NDB_No     Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  \
# 3    1004   CHEESE BLUE      42.41         353        21.40          28.74
# 4    1005  CHEESE BRICK      41.11         371        23.24          29.68
#
#    Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  ...  Vit_A_IU  \
# 3     5.11            2.34           0.0           0.50  ...     721.0
# 4     3.18            2.79           0.0           0.51  ...    1080.0
#
#    Vit_A_RAE  Vit_E_(mg)  Vit_D_mcg  Vit_D_IU  Vit_K_(mcg)  FA_Sat_(g)  \
# 3      198.0        0.25        0.5      21.0          2.4      18.669
# 4      292.0        0.26        0.5      22.0          2.5      18.764
#
#    FA_Mono_(g)  FA_Poly_(g)  Cholestrl_(mg)
# 3        7.778        0.800            75.0
# 4        8.598        0.784            94.0
#
# [2 rows x 36 columns]

# %%
print(test.head(2))
# Out:
#    NDB_No                 Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001          BUTTER WITH SALT      15.87         717         0.85
# 1    1002  BUTTER WHIPPED WITH SALT      15.87         717         0.85
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  ...  \
# 0          81.11     2.11            0.06           0.0           0.06  ...
# 1          81.11     2.11            0.06           0.0           0.06  ...
#
#    Vit_A_IU  Vit_A_RAE  Vit_E_(mg)  Vit_D_mcg  Vit_D_IU  Vit_K_(mcg)  \
# 0    2499.0      684.0        2.32        1.5      60.0          7.0
# 1    2499.0      684.0        2.32        1.5      60.0          7.0
#
#    FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)  Cholestrl_(mg)
# 0      51.368       21.021        3.043           215.0
# 1      50.489       23.426        3.012           219.0
#
# [2 rows x 36 columns]

# %%
print(test.loc[[3, 400, 150]])
# Out:
#      NDB_No                                 Shrt_Desc  Water_(g)  Energ_Kcal  \
# 3      1004                               CHEESE BLUE      42.41         353
# 400    3163  BABYFOOD FRUIT BANANAS W/APPLS&PEARS STR      79.00          83
# 150    1172                    EGG WHITE RAW FRZ PAST      88.97          46
#
#      Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  \
# 3           21.4          28.74     5.11            2.34           0.0
# 400          0.9           0.22     0.57           19.31           1.4
# 150          9.3           0.04     0.43            1.26           0.0
#
#      Sugar_Tot_(g)  ...  Vit_A_IU  Vit_A_RAE  Vit_E_(mg)  Vit_D_mcg  Vit_D_IU  \
# 3             0.50  ...     721.0      198.0        0.25        0.5      21.0
# 400          12.76  ...      56.0        3.0        0.08        0.0       0.0
# 150           0.20  ...       0.0        0.0        0.00        0.0       0.0
#
# ...

# %%
num_rows = test.shape[0]
print(num_rows)
print("------------LAST ROW ---------------")
print(test.tail())
last_rows = test.loc[1]
print(last_rows)
# Out:
# 8618
# ------------LAST ROW ---------------
#       NDB_No                   Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 8613   83110             MACKEREL SALTED      43.00         305        18.50
# 8614   90240  SCALLOP (BAY&SEA) CKD STMD      70.25         111        20.54
# 8615   90480                  SYRUP CANE      26.00         269         0.00
# 8616   90560                   SNAIL RAW      79.20          90        16.10
# 8617   93600            TURTLE GREEN RAW      78.50          89        19.80
#
#       Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  \
# 8613          25.10    13.40            0.00           0.0            0.0
# 8614           0.84     2.97            5.41           0.0            0.0
# 8615           0.00     0.86           73.14           0.0           73.2
# 8616           1.40     1.30            2.00           0.0            0.0
# 8617           0.50     1.20            0.00           0.0            0.0
#
# ...

# %%
naaa = "Shrt_Desc"
names = test[naaa]
print(names)
# Out:
# 0                 BUTTER WITH SALT
# 1         BUTTER WHIPPED WITH SALT
# 2             BUTTER OIL ANHYDROUS
# 3                      CHEESE BLUE
# 4                     CHEESE BRICK
#                    ...
# 8613               MACKEREL SALTED
# 8614    SCALLOP (BAY&SEA) CKD STMD
# 8615                    SYRUP CANE
# 8616                     SNAIL RAW
# 8617              TURTLE GREEN RAW
# Name: Shrt_Desc, Length: 8618, dtype: str

# %%
print(names[1: 5])
# Out:
# 1    BUTTER WHIPPED WITH SALT
# 2        BUTTER OIL ANHYDROUS
# 3                 CHEESE BLUE
# 4                CHEESE BRICK
# Name: Shrt_Desc, dtype: str

# %%
print(names.loc[[1, 2, 3]])
# Out:
# 1    BUTTER WHIPPED WITH SALT
# 2        BUTTER OIL ANHYDROUS
# 3                 CHEESE BLUE
# Name: Shrt_Desc, dtype: str
# 8617    TURTLE GREEN RAW
# 8616           SNAIL RAW
# Name: Shrt_Desc, dtype: str

# %%
zinc = "Zinc_(mg)"
copp = "Copper_(mg)"

column_names = [zinc, copp]
print(column_names)

zinc_copper = test[column_names]
sum = test[zinc] + test[copp]
zinc_copper["sum"] = sum
zinc_copper.columns = ["zinc", "copp", "sum"]
zinc_copper.sort_values(by="sum",  ascending=False)

print(zinc_copper)
# Out:
# ['Zinc_(mg)', 'Copper_(mg)']
#       zinc   copp    sum
# 0     0.09  0.000  0.090
# 1     0.05  0.016  0.066
# 2     0.01  0.001  0.011
# 3     2.66  0.040  2.700
# 4     2.60  0.024  2.624
# ...    ...    ...    ...
# 8613  1.10  0.100  1.200
# 8614  1.55  0.033  1.583
# 8615  0.19  0.020  0.210
# 8616  1.00  0.400  1.400
# 8617  1.00  0.250  1.250
#
# [8618 rows x 3 columns]

# %%
col_names = test.columns.tolist()
grams = []
for c in col_names:
    if c.endswith("(g)"):
        grams.append(c)

data = test[grams]
print(data.head(3))
# Out:
#    Water_(g)  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  \
# 0      15.87         0.85          81.11     2.11            0.06
# 1      15.87         0.85          81.11     2.11            0.06
# 2       0.24         0.28          99.48     0.00            0.00
#
#    Fiber_TD_(g)  Sugar_Tot_(g)  FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)
# 0           0.0           0.06      51.368       21.021        3.043
# 1           0.0           0.06      50.489       23.426        3.012
# 2           0.0           0.00      61.924       28.732        3.694
