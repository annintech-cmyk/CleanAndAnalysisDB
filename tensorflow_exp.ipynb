# %%
import sys
print(sys.version)
# Out:
# 3.14.0 (v3.14.0:ebf955df7a8, Oct  7 2025, 08:20:14) [Clang 16.0.0 (clang-1600.0.26.6)]

# %%
import sys
print(sys.version)  # Should show 3.11.x
import tensorflow as tf
print(tf.__version__) # Should work

# %%
import tensorflow as tf
print(tf.__version__)

# %%
import tensorflow as tf
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Documents/post_projects/Python/Analysis/.venv/lib/python3.14/site-packages/tensorflow/python/pywrap_tensorflow.py:58
#      56   sys.setdlopenflags(_default_dlopen_flags | ctypes.RTLD_LOCAL)
# ---> 58 from tensorflow.python.pywrap_tensorflow_internal import *
#      59 from tensorflow.python.pywrap_tensorflow_internal import __version__
#
# File ~/Documents/post_projects/Python/Analysis/.venv/lib/python3.14/site-packages/tensorflow/python/pywrap_tensorflow_internal.py:28
#      27         return _mod
# ---> 28 _pywrap_tensorflow_internal = swig_import_helper()
#      29 del swig_import_helper
#
# File ~/Documents/post_projects/Python/Analysis/.venv/lib/python3.14/site-packages/tensorflow/python/pywrap_tensorflow_internal.py:15, in swig_import_helper()
#      14 from os.path import dirname
# ---> 15 import imp
# ...
